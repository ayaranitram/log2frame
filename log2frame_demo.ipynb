# %% [markdown]
# # `log2frame`
#
# Install it from [pypi.org](https://pypi.org/project/log2frame/) repository:
#
# `pip install --upgrade log2frame`

# %%
import log2frame
# Out:
# units dictionary loaded from cache...
# units network loaded from cache...
# loaded unyts version 0.5.17

# %% [markdown]
# # loading log data from .LAS or .DLIS files
#
# Both formats are readed calling the function **`.read()`** with the _path to the file_, _list of paths to files_ or _file pattern_ that will be treated by `glob` to find the files:
#
# `my_log =`**`log2frame.read(`**_`path_to_file`_**`)`**
#
# And the output from the function will be the same, independently from the input format.
#
# # reading .LAS files

# %%
las_path = './sampledata/A12a_CPP_A7_1225in_RM_397-1186mMD.LAS'

# %%
las = log2frame.read(las_path)

# %% [markdown]
# The output of `log2frame.read` function when loading _a single log file_ is a **Log** instance, that contains:
# - the log header,
# - the curves data and
# - the curves units
#
# In case of _loading several log files_ at once a **Pack** instance, that contains one **Log** pero file, is returned.

# %%
type(las)
# Out:
# Log

# %% [markdown]
# ## log header
# The attribute **`.header`** contains a DataFrame with the header information:

# %%
las.header
# Out:
#           unit                   value  \
# VERS                               2.0
# WRAP                                NO
# STRT         M                   397.0
# STOP         M               1185.9768
# STEP         M                  0.1524
# NULL                           -999.25
# COMP                           Chevron
# WELL                       A12a-CPP-A7
# FLD                                A12
# LOC             North Sea Dutch Sector
# PROV
# CNTY
# STAT
# CTRY                   The Netherlands
# SRVC                Schlimberger D & M
# DATE                         30-Sep-07
# UWI
# API
# DEPT         M
# P16H_UNC  OHMM
# P22H_UNC  OHMM
# P28H_UNC  OHMM
# P34H_UNC  OHMM
# P40H_UNC  OHMM
# A16H_UNC  OHMM
# A22H_UNC  OHMM
# A28H_UNC  OHMM
# A34H_UNC  OHMM
# A40H_UNC  OHMM
# DRHB      G/C3
# DRHO      G/C3
# ROBB      G/C3
# RHOB      G/C3
# TNPH        PU
# GR_ARC    GAPI
# HORD        IN
# VERD        IN
# ROP5_RM   M/HR
#
#                                                       descr
# VERS                  CWLS log ASCII standard - Version 2.0
# WRAP                                One line per depth step
# STRT                                            START INDEX
# STOP                                             STOP INDEX
# STEP                                                   STEP
# NULL                                             NULL VALUE
# COMP                                                COMPANY
# WELL                                                   WELL
# FLD                                                   FIELD
# LOC                                                LOCATION
# PROV                                               PROVINCE
# CNTY                                                 COUNTY
# STAT                                                  STATE
# CTRY                                                COUNTRY
# SRVC                                        SERVICE COMPANY
# DATE                                               LOG DATE
# UWI                                          UNIQUE WELL ID
# API                                              API NUMBER
# DEPT                                          Bit Depth 2hz
# P16H_UNC  ARC Non-BHCorr Phase-Shift Resistivity 16-in. ...
# P22H_UNC  ARC Non-BHCorr Phase-Shift Resistivity 22-in. ...
# P28H_UNC  ARC Non-BHCorr Phase-Shift Resistivity 28-in. ...
# P34H_UNC  ARC Non-BHCorr Phase-Shift Resistivity 34-in. ...
# P40H_UNC  ARC Non-BHCorr Phase-Shift Resistivity 40-in. ...
# A16H_UNC  ARC Non-BHCorr Attenuation Resistivity 16-in. ...
# A22H_UNC  ARC Non-BHCorr Attenuation Resistivity 22-in. ...
# A28H_UNC  ARC Non-BHCorr Attenuation Resistivity 28-in. ...
# A34H_UNC  ARC Non-BHCorr Attenuation Resistivity 34-in. ...
# A40H_UNC  ARC Non-BHCorr Attenuation Resistivity 40-in. ...
# DRHB                        Bulk Density Correction, Bottom
# DRHO                                Bulk Density Correction
# ROBB                                   Bulk Density, Bottom
# RHOB                                           Bulk Density
# TNPH      Thermal Neutron Porosity (Ratio Method) in Sel...
# GR_ARC                                        ARC Gamma Ray
# HORD                               Horizontal Hole Diameter
# VERD                                 Vertical Hole Diameter
# ROP5_RM         Rate of Penetration, Averaged over Last 5ft

# %% [markdown]
# ### well name
# The well name has been extracted from the `.header` and can be accessed directly from the attribute **`.name`**:

# %%
las.name
# Out:
# 'A12a-CPP-A7'

# %% [markdown]
# ### path to the source file
# The path to the source file is stored in the attribute **`.source`**:

# %%
las.source
# Out:
# './sampledata/A12a_CPP_A7_1225in_RM_397-1186mMD.LAS'

# %% [markdown]
# ## log curves
# The attitribute **`.data`** contains a *DataFrame* or *SimDataFrame* with the curves values:

# %%
las.data
# Out:
#         P16H_UNC P22H_UNC P28H_UNC P34H_UNC P40H_UNC A16H_UNC A22H_UNC  \
#             OHMM     OHMM     OHMM     OHMM     OHMM     OHMM     OHMM
# DEPT
# 397.00      2.64     2.70     1.94     1.19     0.83   300.00     6.23
# 397.15      1.03     1.39     1.27     1.04     1.08     0.31     0.82
# 397.31      0.87     1.28     1.24     1.00     1.03     0.32     0.86
# 397.46      0.97     1.10     0.98     0.95     1.26     0.57     0.42
# 397.61      1.10     0.89     0.68     0.74     1.33     0.57     0.45
# ...          ...      ...      ...      ...      ...      ...      ...
# 1185.37      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1185.52      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1185.67      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1185.82      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1185.98      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         A28H_UNC A34H_UNC A40H_UNC  DRHB  DRHO  ROBB  RHOB   TNPH GR_ARC HORD  \
#             OHMM     OHMM     OHMM  G/C3  G/C3  G/C3  G/C3     PU   GAPI   IN
# DEPT
# 397.00      1.65     1.27     1.10 -0.01 -0.03  1.82  1.71  50.94  34.16  NaN
# 397.15      1.62     1.29     1.00  0.24  0.15  1.95  1.74  58.85  35.27  NaN
# 397.31      1.65     1.22     0.87  0.16  0.08  1.89  1.66  67.36  35.80  NaN
# 397.46      0.37     0.59     2.63  0.12  0.04  1.90  1.64  71.94  37.25  NaN
# 397.61      0.40     0.60     1.86  0.11  0.03  1.92  1.65  59.54  40.42  NaN
# ...          ...      ...      ...   ...   ...   ...   ...    ...    ...  ...
# 1185.37      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN  NaN
# 1185.52      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN  NaN
# 1185.67      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN  NaN
# 1185.82      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN  NaN
# 1185.98      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN  NaN
#
#         VERD ROP5_RM
#           IN    M/HR
# DEPT
# 397.00   NaN    9.10
# 397.15   NaN    9.10
# 397.31   NaN    7.62
# 397.46   NaN    9.57
# 397.61   NaN   10.41
# ...      ...     ...
# 1185.37  NaN   32.66
# 1185.52  NaN   32.47
# 1185.67  NaN   32.66
# 1185.82  NaN   32.85
# 1185.98  NaN   32.85
#
# [5178 rows x 19 columns]

# %% [markdown]
# ## curves units
# The attribute **`.units`** contains the curves units as described in the log file:

# %%
las.units
# Out:
# STRT           M
# STOP           M
# STEP           M
# NULL
# COMP
# WELL
# FLD
# LOC
# PROV
# CNTY
# STAT
# CTRY
# SRVC
# DATE
# UWI
# API
# DEPT           M
# P16H_UNC    OHMM
# P22H_UNC    OHMM
# P28H_UNC    OHMM
# P34H_UNC    OHMM
# P40H_UNC    OHMM
# A16H_UNC    OHMM
# A22H_UNC    OHMM
# A28H_UNC    OHMM
# A34H_UNC    OHMM
# A40H_UNC    OHMM
# DRHB        G/C3
# DRHO        G/C3
# ROBB        G/C3
# RHOB        G/C3
# TNPH          PU
# GR_ARC      GAPI
# HORD          IN
# VERD          IN
# ROP5_RM     M/HR
# Name: curves_units, dtype: object

# %% [markdown]
# This units information is already contained in the `.data` attribute if **SimDataFrame** has been used while loading the data.

# %% [markdown]
# ## The log index
#
# The **index** of the curves can be defined with the parameter **`index`** when calling the `log2frame.read` function. By default the expected _index mnemonic_ is 'DEPTH' and will be set as index of the DataFrame if available in the curves.
#
# The attribute **`.index`** points to the current index of the DataFrame in `.data` attribute:

# %%
las.index
# Out:
# Float64Index([  397.0,  397.15,  397.31,  397.46,  397.61,  397.76,  397.92,
#                398.07,  398.22,  398.37,
#               ...
#               1184.61, 1184.76, 1184.91, 1185.06, 1185.21, 1185.37, 1185.52,
#               1185.67, 1185.82, 1185.98],
#              dtype='float64', name='DEPT', length=5178)

# %% [markdown]
# The _mnemonic_ of the index curve can be accessed via the property **`.index_name`** and the _units_ by the property **`.index_units`**:

# %%
las.index_name
# Out:
# 'DEPT'

# %%
las.index_units
# Out:
# 'M'

# %% [markdown]
# ### The `.index_to()` method
#
# The index values can be converted to other units using the **`.index_to`** method, providing a `str` for the desired units or another **Log** instance to take the _index units_ from that one:

# %%
las_ft = las.index_to('ft')
las_ft
# Out:
#             P16H_UNC P22H_UNC P28H_UNC P34H_UNC P40H_UNC A16H_UNC A22H_UNC  \
#                 OHMM     OHMM     OHMM     OHMM     OHMM     OHMM     OHMM
# DEPT
# 1302.493438     2.64     2.70     1.94     1.19     0.83   300.00     6.23
# 1302.985564     1.03     1.39     1.27     1.04     1.08     0.31     0.82
# 1303.510499     0.87     1.28     1.24     1.00     1.03     0.32     0.86
# 1304.002625     0.97     1.10     0.98     0.95     1.26     0.57     0.42
# 1304.494751     1.10     0.89     0.68     0.74     1.33     0.57     0.45
# ...              ...      ...      ...      ...      ...      ...      ...
# 3889.009186      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3889.501312      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3889.993438      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3890.485564      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3891.010499      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             A28H_UNC A34H_UNC A40H_UNC  DRHB  DRHO  ROBB  RHOB   TNPH GR_ARC  \
#                 OHMM     OHMM     OHMM  G/C3  G/C3  G/C3  G/C3     PU   GAPI
# DEPT
# 1302.493438     1.65     1.27     1.10 -0.01 -0.03  1.82  1.71  50.94  34.16
# 1302.985564     1.62     1.29     1.00  0.24  0.15  1.95  1.74  58.85  35.27
# 1303.510499     1.65     1.22     0.87  0.16  0.08  1.89  1.66  67.36  35.80
# 1304.002625     0.37     0.59     2.63  0.12  0.04  1.90  1.64  71.94  37.25
# 1304.494751     0.40     0.60     1.86  0.11  0.03  1.92  1.65  59.54  40.42
# ...              ...      ...      ...   ...   ...   ...   ...    ...    ...
# 3889.009186      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3889.501312      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3889.993438      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3890.485564      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3891.010499      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
#
#             HORD VERD ROP5_RM
#               IN   IN    M/HR
# DEPT
# 1302.493438  NaN  NaN    9.10
# 1302.985564  NaN  NaN    9.10
# 1303.510499  NaN  NaN    7.62
# 1304.002625  NaN  NaN    9.57
# 1304.494751  NaN  NaN   10.41
# ...          ...  ...     ...
# 3889.009186  NaN  NaN   32.66
# 3889.501312  NaN  NaN   32.47
# 3889.993438  NaN  NaN   32.66
# 3890.485564  NaN  NaN   32.85
# 3891.010499  NaN  NaN   32.85
#
# [5178 rows x 19 columns]

# %% [markdown]
# The new Log instance has the index converted to the desired units:

# %%
las_ft.index_units
# Out:
# 'ft'

# %% [markdown]
# # reading .DLIS files
#
# To read .DLIS files the procedure and output are the same as reading .LAS files, use **`log2frame.read()`** with the path to the file as argument:

# %%
dlis_path = r"./sampledata/G030088973__A-5-1__REFS12348052.dlis"

# %%
dlis = log2frame.read(dlis_path)

# %%
type(dlis)
# Out:
# Log

# %% [markdown]
# ## log header

# %%
dlis.header
# Out:
#       long_name                                             values
# name
# CDFT        NaN                                         KCl Glycol
# CDTL        NaN                                            July 99
# CDTP        NaN                                         31 July 99
# CITP        NaN                                       4550-13050ft
# CJBN        NaN                                            AB99026
# CN          NaN                                       AMERADA HESS
# CPAT        NaN                                           Aberdeen
# CPBY        NaN                                          Jim Craig
# DMF         NaN                                                 DF
# FL1         NaN                                      55:40:54.106N
# FL2         NaN                                      03:31:13.844E
# FN          NaN                                        Exploration
# HDRT        NaN                                              CMPPR
# LMF         NaN                                                 DF
# PDAT        NaN                                                MSL
# R1          NaN  Unconpensated resistivity curves over interval...
# R2          NaN                        medium transmitter failure.
# R3          NaN            UU2P - Uncompensated upper medium Phase
# R4          NaN      UU2A - Uncompensated upper medium Attenuation
# R5          NaN  Resistivity reading above tool spec over inter...
# STAT        NaN                                        Netherlands
# WN          NaN                                              A/5-1
# APD         NaN                                                120
# EDF         NaN                                                120
# EGL         NaN                                               -154
# EPD         NaN                                                  0

# %% [markdown]
# ### well name

# %%
dlis.name
# Out:
# 'A/5-1'

# %% [markdown]
# ### source path

# %%
dlis.source
# Out:
# './sampledata/G030088973__A-5-1__REFS12348052.dlis'

# %% [markdown]
# ### log curves

# %%
dlis.data
# Out:
#         FRAMENO         GRC    R25A    R25P         R55A         R55P    UU2A  \
#             NaN         API   ohm.m   ohm.m        ohm.m        ohm.m   ohm.m
# DEPT
# 13033.0       1 -999.250000 -999.25 -999.25  -999.250000  -999.250000 -999.25
# 13032.5       2 -999.250000 -999.25 -999.25  -999.250000  -999.250000 -999.25
# 13032.0       3 -999.250000 -999.25 -999.25  -999.250000  -999.250000 -999.25
# 13031.5       4 -999.250000 -999.25 -999.25  -999.250000  -999.250000 -999.25
# 13031.0       5 -999.250000 -999.25 -999.25  -999.250000  -999.250000 -999.25
# ...         ...         ...     ...     ...          ...          ...     ...
# 4552.0    16963   96.319992    0.11    0.26   818.989990  1572.599854 -999.25
# 4551.5    16964   99.599991    0.42    0.36  3072.089844   936.630005 -999.25
# 4551.0    16965  101.629990    0.20    0.57   541.869995  3344.879883 -999.25
# 4550.5    16966  102.500000    0.15    0.41  1166.399902  1639.699951 -999.25
# 4550.0    16967  103.910004    0.16    0.63  1323.810059  2836.089844 -999.25
#
#            UU2P
#           ohm.m
# DEPT
# 13033.0 -999.25
# 13032.5 -999.25
# 13032.0 -999.25
# 13031.5 -999.25
# 13031.0 -999.25
# ...         ...
# 4552.0  -999.25
# 4551.5  -999.25
# 4551.0  -999.25
# 4550.5  -999.25
# 4550.0  -999.25
#
# [16967 rows x 8 columns]

# %% [markdown]
# ## curves units

# %%
dlis.units
# Out:
# DEPT       ft
# GRC       API
# R25A    ohm.m
# R25P    ohm.m
# R55A    ohm.m
# R55P    ohm.m
# UU2A    ohm.m
# UU2P    ohm.m
# Name: frame_units, dtype: object

# %% [markdown]
# ## The log index

# %%
dlis.index
# Out:
# Float64Index([13033.0, 13032.5, 13032.0, 13031.5, 13031.0, 13030.5, 13030.0,
#               13029.5, 13029.0, 13028.5,
#               ...
#                4554.5,  4554.0,  4553.5,  4553.0,  4552.5,  4552.0,  4551.5,
#                4551.0,  4550.5,  4550.0],
#              dtype='float64', name='DEPT', length=16967)

# %%
dlis.index_name
# Out:
# 'DEPT'

# %%
dlis.index_units
# Out:
# 'ft'

# %% [markdown]
# ### `index_to()`

# %%
dlis.index_to('m')
# Out:
#           FRAMENO         GRC    R25A    R25P         R55A         R55P  \
#               NaN         API   ohm.m   ohm.m        ohm.m        ohm.m
# DEPT
# 3972.4584       1 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 3972.3060       2 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 3972.1536       3 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 3972.0012       4 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 3971.8488       5 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# ...           ...         ...     ...     ...          ...          ...
# 1387.4496   16963   96.319992    0.11    0.26   818.989990  1572.599854
# 1387.2972   16964   99.599991    0.42    0.36  3072.089844   936.630005
# 1387.1448   16965  101.629990    0.20    0.57   541.869995  3344.879883
# 1386.9924   16966  102.500000    0.15    0.41  1166.399902  1639.699951
# 1386.8400   16967  103.910004    0.16    0.63  1323.810059  2836.089844
#
#              UU2A    UU2P
#             ohm.m   ohm.m
# DEPT
# 3972.4584 -999.25 -999.25
# 3972.3060 -999.25 -999.25
# 3972.1536 -999.25 -999.25
# 3972.0012 -999.25 -999.25
# 3971.8488 -999.25 -999.25
# ...           ...     ...
# 1387.4496 -999.25 -999.25
# 1387.2972 -999.25 -999.25
# 1387.1448 -999.25 -999.25
# 1386.9924 -999.25 -999.25
# 1386.8400 -999.25 -999.25
#
# [16967 rows x 8 columns]

# %% [markdown]
# # reading .LIS files

# %%
lis_path = './sampledata/a0501t01.lis'

# %%
lis = log2frame.read(lis_path)
# Out:
# Missing Header Record - File structure is broken

# %%
type(lis)
# Out:
# Log

# %% [markdown]
# ## .LIS with multiple runs
#
# A `Pack` will be returned in case there are _several runs_ (with data) in _a single .LIS file_.
# Inside that `Pack` there will be a `Log` for each run with data.

# %% [markdown]
# ## log header

# %%
lis.header
# Out:
#                         values units STAT PUNI TUNI VALU
# file_name           HES   .001
# date_of_generation    06/21/99
# name
# service_name
# reel_date

# %% [markdown]
# ## log curves

# %%
lis.data
# Out:
#         physical_file logical_file sample_rate        GRC     R25A    R25P  \
#                   NaN          NaN         NaN         API    OHMM    OHMM
# DEPT
# 4550.0              0            0           1  103.910004    0.16    0.63
# 4550.5              0            0           1  102.500000    0.15    0.41
# 4551.0              0            0           1  101.629990    0.20    0.57
# 4551.5              0            0           1   99.599991    0.42    0.36
# 4552.0              0            0           1   96.319992    0.11    0.26
# ...               ...          ...         ...         ...     ...     ...
# 13031.0             0            0           1 -999.250000 -999.25 -999.25
# 13031.5             0            0           1 -999.250000 -999.25 -999.25
# 13032.0             0            0           1 -999.250000 -999.25 -999.25
# 13032.5             0            0           1 -999.250000 -999.25 -999.25
# 13033.0             0            0           1 -999.250000 -999.25 -999.25
#
#                 R55A         R55P    UU2A    UU2P
#                 OHMM         OHMM    OHMM    OHMM
# DEPT
# 4550.0   1323.810059  2836.089844 -999.25 -999.25
# 4550.5   1166.399902  1639.699951 -999.25 -999.25
# 4551.0    541.869995  3344.879883 -999.25 -999.25
# 4551.5   3072.089844   936.630005 -999.25 -999.25
# 4552.0    818.989990  1572.599854 -999.25 -999.25
# ...              ...          ...     ...     ...
# 13031.0  -999.250000  -999.250000 -999.25 -999.25
# 13031.5  -999.250000  -999.250000 -999.25 -999.25
# 13032.0  -999.250000  -999.250000 -999.25 -999.25
# 13032.5  -999.250000  -999.250000 -999.25 -999.25
# 13033.0  -999.250000  -999.250000 -999.25 -999.25
#
# [16967 rows x 10 columns]

# %% [markdown]
# ## curves units

# %%
lis.units
# Out:
# DEPT    F
# GRC     API
# R25A    OHMM
# R25P    OHMM
# R55A    OHMM
# R55P    OHMM
# UU2A    OHMM
# UU2P    OHMM
# dtype: object

# %% [markdown]
# ## The log index

# %%
lis.index
# Out:
# Float64Index([ 4550.0,  4550.5,  4551.0,  4551.5,  4552.0,  4552.5,  4553.0,
#                4553.5,  4554.0,  4554.5,
#               ...
#               13028.5, 13029.0, 13029.5, 13030.0, 13030.5, 13031.0, 13031.5,
#               13032.0, 13032.5, 13033.0],
#              dtype='float64', name='DEPT', length=16967)

# %%
lis.index_name
# Out:
# 'DEPT'

# %%
lis.index_units
# Out:
# 'F   '

# %% [markdown]
# ### `index_to()`

# %%
lis.index_to('m')
# Out:
# WARNING:root:index units not converted!
#         physical_file logical_file sample_rate        GRC     R25A    R25P  \
#                   NaN          NaN         NaN         API    OHMM    OHMM
# DEPT
# 4550.0              0            0           1  103.910004    0.16    0.63
# 4550.5              0            0           1  102.500000    0.15    0.41
# 4551.0              0            0           1  101.629990    0.20    0.57
# 4551.5              0            0           1   99.599991    0.42    0.36
# 4552.0              0            0           1   96.319992    0.11    0.26
# ...               ...          ...         ...         ...     ...     ...
# 13031.0             0            0           1 -999.250000 -999.25 -999.25
# 13031.5             0            0           1 -999.250000 -999.25 -999.25
# 13032.0             0            0           1 -999.250000 -999.25 -999.25
# 13032.5             0            0           1 -999.250000 -999.25 -999.25
# 13033.0             0            0           1 -999.250000 -999.25 -999.25
#
#                 R55A         R55P    UU2A    UU2P
#                 OHMM         OHMM    OHMM    OHMM
# DEPT
# 4550.0   1323.810059  2836.089844 -999.25 -999.25
# 4550.5   1166.399902  1639.699951 -999.25 -999.25
# 4551.0    541.869995  3344.879883 -999.25 -999.25
# 4551.5   3072.089844   936.630005 -999.25 -999.25
# 4552.0    818.989990  1572.599854 -999.25 -999.25
# ...              ...          ...     ...     ...
# 13031.0  -999.250000  -999.250000 -999.25 -999.25
# 13031.5  -999.250000  -999.250000 -999.25 -999.25
# 13032.0  -999.250000  -999.250000 -999.25 -999.25
# 13032.5  -999.250000  -999.250000 -999.25 -999.25
# 13033.0  -999.250000  -999.250000 -999.25 -999.25
#
# [16967 rows x 10 columns]

# %% [markdown]
# Notice the warning message stating that _index units has not been converted_. The index units are wrongly defines as **'F'**, that is not abreviation for _feet_.
#
# The index units can be corrected using the method `.set_index_units()`:

# %%
lis.set_index_units('ft')

# %%
lis
# Out:
#         physical_file logical_file sample_rate        GRC     R25A    R25P  \
#                   NaN          NaN         NaN         API    OHMM    OHMM
# DEPT
# 4550.0              0            0           1  103.910004    0.16    0.63
# 4550.5              0            0           1  102.500000    0.15    0.41
# 4551.0              0            0           1  101.629990    0.20    0.57
# 4551.5              0            0           1   99.599991    0.42    0.36
# 4552.0              0            0           1   96.319992    0.11    0.26
# ...               ...          ...         ...         ...     ...     ...
# 13031.0             0            0           1 -999.250000 -999.25 -999.25
# 13031.5             0            0           1 -999.250000 -999.25 -999.25
# 13032.0             0            0           1 -999.250000 -999.25 -999.25
# 13032.5             0            0           1 -999.250000 -999.25 -999.25
# 13033.0             0            0           1 -999.250000 -999.25 -999.25
#
#                 R55A         R55P    UU2A    UU2P
#                 OHMM         OHMM    OHMM    OHMM
# DEPT
# 4550.0   1323.810059  2836.089844 -999.25 -999.25
# 4550.5   1166.399902  1639.699951 -999.25 -999.25
# 4551.0    541.869995  3344.879883 -999.25 -999.25
# 4551.5   3072.089844   936.630005 -999.25 -999.25
# 4552.0    818.989990  1572.599854 -999.25 -999.25
# ...              ...          ...     ...     ...
# 13031.0  -999.250000  -999.250000 -999.25 -999.25
# 13031.5  -999.250000  -999.250000 -999.25 -999.25
# 13032.0  -999.250000  -999.250000 -999.25 -999.25
# 13032.5  -999.250000  -999.250000 -999.25 -999.25
# 13033.0  -999.250000  -999.250000 -999.25 -999.25
#
# [16967 rows x 10 columns]

# %%
lis.index_to('m')
# Out:
#           physical_file logical_file sample_rate        GRC     R25A    R25P  \
#                     NaN          NaN         NaN         API    OHMM    OHMM
# DEPT
# 1386.8400             0            0           1  103.910004    0.16    0.63
# 1386.9924             0            0           1  102.500000    0.15    0.41
# 1387.1448             0            0           1  101.629990    0.20    0.57
# 1387.2972             0            0           1   99.599991    0.42    0.36
# 1387.4496             0            0           1   96.319992    0.11    0.26
# ...                 ...          ...         ...         ...     ...     ...
# 3971.8488             0            0           1 -999.250000 -999.25 -999.25
# 3972.0012             0            0           1 -999.250000 -999.25 -999.25
# 3972.1536             0            0           1 -999.250000 -999.25 -999.25
# 3972.3060             0            0           1 -999.250000 -999.25 -999.25
# 3972.4584             0            0           1 -999.250000 -999.25 -999.25
#
#                   R55A         R55P    UU2A    UU2P
#                   OHMM         OHMM    OHMM    OHMM
# DEPT
# 1386.8400  1323.810059  2836.089844 -999.25 -999.25
# 1386.9924  1166.399902  1639.699951 -999.25 -999.25
# 1387.1448   541.869995  3344.879883 -999.25 -999.25
# 1387.2972  3072.089844   936.630005 -999.25 -999.25
# 1387.4496   818.989990  1572.599854 -999.25 -999.25
# ...                ...          ...     ...     ...
# 3971.8488  -999.250000  -999.250000 -999.25 -999.25
# 3972.0012  -999.250000  -999.250000 -999.25 -999.25
# 3972.1536  -999.250000  -999.250000 -999.25 -999.25
# 3972.3060  -999.250000  -999.250000 -999.25 -999.25
# 3972.4584  -999.250000  -999.250000 -999.25 -999.25
#
# [16967 rows x 10 columns]

# %% [markdown]
# # using `Pandas.DataFrame` instead of `SimDataFrame`
#
# If available, `log2frame.read()` will use `SimDataFrame` to store the curves data, but if that package is not available it will use `DataFrame` from Pandas library.
#
# To change that default behaviour - _to always use `pa.DataFrame`_ - the paramenter `use_simpandas` should be set to **False** to overide the automatic selection:
#
# `my_log =`**`log2frame.read(`**_`path_to_file, use_simpandas=False`_**`)`**

# %%
log_pd = log2frame.read(dlis_path, use_simpandas=False)
log_pd
# Out:
#          FRAMENO         GRC    R25A    R25P         R55A         R55P  \
# DEPT
# 13033.0        1 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 13032.5        2 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 13032.0        3 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 13031.5        4 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 13031.0        5 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# ...          ...         ...     ...     ...          ...          ...
# 4552.0     16963   96.319992    0.11    0.26   818.989990  1572.599854
# 4551.5     16964   99.599991    0.42    0.36  3072.089844   936.630005
# 4551.0     16965  101.629990    0.20    0.57   541.869995  3344.879883
# 4550.5     16966  102.500000    0.15    0.41  1166.399902  1639.699951
# 4550.0     16967  103.910004    0.16    0.63  1323.810059  2836.089844
#
#            UU2A    UU2P
# DEPT
# 13033.0 -999.25 -999.25
# 13032.5 -999.25 -999.25
# 13032.0 -999.25 -999.25
# 13031.5 -999.25 -999.25
# 13031.0 -999.25 -999.25
# ...         ...     ...
# 4552.0  -999.25 -999.25
# 4551.5  -999.25 -999.25
# 4551.0  -999.25 -999.25
# 4550.5  -999.25 -999.25
# 4550.0  -999.25 -999.25
#
# [16967 rows x 8 columns]

# %%
log_pd.header
# Out:
#       long_name                                             values
# name
# CDFT        NaN                                         KCl Glycol
# CDTL        NaN                                            July 99
# CDTP        NaN                                         31 July 99
# CITP        NaN                                       4550-13050ft
# CJBN        NaN                                            AB99026
# CN          NaN                                       AMERADA HESS
# CPAT        NaN                                           Aberdeen
# CPBY        NaN                                          Jim Craig
# DMF         NaN                                                 DF
# FL1         NaN                                      55:40:54.106N
# FL2         NaN                                      03:31:13.844E
# FN          NaN                                        Exploration
# HDRT        NaN                                              CMPPR
# LMF         NaN                                                 DF
# PDAT        NaN                                                MSL
# R1          NaN  Unconpensated resistivity curves over interval...
# R2          NaN                        medium transmitter failure.
# R3          NaN            UU2P - Uncompensated upper medium Phase
# R4          NaN      UU2A - Uncompensated upper medium Attenuation
# R5          NaN  Resistivity reading above tool spec over inter...
# STAT        NaN                                        Netherlands
# WN          NaN                                              A/5-1
# APD         NaN                                                120
# EDF         NaN                                                120
# EGL         NaN                                               -154
# EPD         NaN                                                  0

# %%
log_pd.units
# Out:
# DEPT       ft
# GRC       API
# R25A    ohm.m
# R25P    ohm.m
# R55A    ohm.m
# R55P    ohm.m
# UU2A    ohm.m
# UU2P    ohm.m
# Name: frame_units, dtype: object

# %%
log_pd.index_units
# Out:
# 'ft'

# %%
log_pd.index_to('in')
# Out:
# converting from 'ft' to 'in
# ft > foot > inch > in
#           FRAMENO         GRC    R25A    R25P         R55A         R55P  \
# DEPT
# 156396.0        1 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 156390.0        2 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 156384.0        3 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 156378.0        4 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# 156372.0        5 -999.250000 -999.25 -999.25  -999.250000  -999.250000
# ...           ...         ...     ...     ...          ...          ...
# 54624.0     16963   96.319992    0.11    0.26   818.989990  1572.599854
# 54618.0     16964   99.599991    0.42    0.36  3072.089844   936.630005
# 54612.0     16965  101.629990    0.20    0.57   541.869995  3344.879883
# 54606.0     16966  102.500000    0.15    0.41  1166.399902  1639.699951
# 54600.0     16967  103.910004    0.16    0.63  1323.810059  2836.089844
#
#             UU2A    UU2P
# DEPT
# 156396.0 -999.25 -999.25
# 156390.0 -999.25 -999.25
# 156384.0 -999.25 -999.25
# 156378.0 -999.25 -999.25
# 156372.0 -999.25 -999.25
# ...          ...     ...
# 54624.0  -999.25 -999.25
# 54618.0  -999.25 -999.25
# 54612.0  -999.25 -999.25
# 54606.0  -999.25 -999.25
# 54600.0  -999.25 -999.25
#
# [16967 rows x 8 columns]

# %% [markdown]
# # reading several log files or colecting several `Log` instances
#
# The same function **`log2frame.read()`** can read several files and collect them together in a **`Pack`** instance.
#
# ## The `Pack` instance
#
# The `Pack` instance contains several `Log` instances, sorted by _well name_ and _source path_, and allows to extract each `Log` by their well name, source path or index number in the Pack.

# %%
pattern = './sampledata/*/*.*'

# %%
las_pack = log2frame.read(pattern)
# Out:
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.
# WARNING:root:The file './sampledata\many\ana01t01.lis' is already loaded. It will be overwritten.

# %% [markdown]
# ### `Pack` summary
#
# The representation of the `Pack` is a summary of the all the loaded logs. This summary can be accessed excuting the method **`.summary()`**:

# %%
las_pack
# Out:
#                                            well  curves  steps index mnemonic  \
# 0                                        ALK001       1  16961           DEPT
# 1        {32CBF15E-C69E-4316-ABD5-8F1549ADA7B1}      36   2253          DEPTH
# 2                                        P11-11       6   2481           DEPT
# 3                                         L5-13      28   1787           DEPT
# 4                                         L5-13      22   1141           DEPT
# 5   Daldrup_HEK-GT-01_USIT_23Jul13_FPM_LF1_FRM2       2  16840           TDEP
# 6                                  HEK-GT-01-S2       1  31116          DEPTH
# 7                                        imf          4      8           DEPT
# 8                                        SHELL        6   1642           DEPT
# 9                                SCHOONEBEEK- 3       2   3518           DEPT
# 10                               SCHOONEBEEK- 3       2    804           DEPT
# 11                               SCHOONEBEEK- 3       2   1786           DEPT
# 12                               SCHOONEBEEK- 3       4    581           DEPT
#
#    index units    min index    max index  \
# 0            M     0.152000  2584.856000
# 1            M   193.000000  2445.000000
# 2            M  2848.100000  3096.100000
# 3            M  3263.625000  3486.875000
# 4            M  3253.625000  3396.125000
# 5           FT   265.333333  3071.833333
# 6            M     0.000000  3111.500000
# 7         M      611.270020   612.329956
# 8         M     3199.942871  3450.031250
# 9            M   245.973600   781.964400
# 10           M   950.000000  1110.600000
# 11           M   700.000000  1057.000000
# 12           M   745.540800   861.540800
#
#                                      curves mnemonics  \
# 0                                                  DT
# 1   ROP, WOB, HOOKLOAD, RPM_BIT, RPM_STRING, TORQU...
# 2                        GR, VSH, NG, PHIE, PHIT, SWE
# 3   BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 4   BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 5                                 EHGR_EDTC, HGR_EDTC
# 6                                                  GR
# 7      physical_file, logical_file, sample_rate, TTGR
# 8   physical_file, logical_file, sample_rate, BCSL...
# 9                                              SN, SP
# 10                                             SN, SP
# 11                                             SN, SP
# 12                                     ES, LN, SN, SP
#
#                                                  path
# 0                     ./sampledata\many\ALK001-DT.las
# 1                 ./sampledata\many\numericaldata.las
# 2   ./sampledata\many\P11-11_reservoir_evaluation.las
# 3    ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 4                       ./sampledata\many\m87ad09.las
# 5   ./sampledata\many\Daldrup_HEK-GT-01_USIT_23Jul...
# 6      ./sampledata\many\5734_hekgt01s2_2013_comp.las
# 7                      ./sampledata\many\ana01t01.lis
# 8                      ./sampledata\many\anl01t01.lis
# 9   ./sampledata\many\SCHOONEBEEK__3_RUN_01_RAW_OH...
# 10  ./sampledata\many\SCHOONEBEEK__3_RUN_04_RAW_OH...
# 11  ./sampledata\many\SCHOONEBEEK__3_RUN_03_RAW_OH...
# 12  ./sampledata\many\SCHOONEBEEK__3_RUN_02_RAW_OH...

# %% [markdown]
# ### getting a `Log` from the `Pack`
#
# A particular **`Log`** can be extracted from the `Pack` by their index in the `.summary()`:

# %%
print('name:', las_pack[2].name)
one_log = las_pack[2]
one_log
# Out:
# name: P11-11
#                 GR       VSH   NG  PHIE      PHIT  SWE
#               gAPI         %      m3/m3     m3/m3
# DEPT
# 2848.1   94.649963  0.599209  0.0   0.0  0.018230  1.0
# 2848.2   97.408981  0.635115  0.0   0.0  0.018166  1.0
# 2848.3  100.315918  0.675204  0.0   0.0  0.018504  1.0
# 2848.4  102.986389  0.712926  0.0   0.0  0.020157  1.0
# 2848.5  105.348854  0.747440  0.0   0.0  0.023463  1.0
# ...            ...       ...  ...   ...       ...  ...
# 3095.7   66.164604  0.295831  0.0   NaN       NaN  NaN
# 3095.8   63.079655  0.269918  0.0   NaN       NaN  NaN
# 3095.9   60.334328  0.247381  0.0   NaN       NaN  NaN
# 3096.0   57.990810  0.228807  0.0   NaN       NaN  NaN
# 3096.1   56.599304  0.218156  0.0   NaN       NaN  NaN
#
# [2481 rows x 6 columns]

# %% [markdown]
# ### getting a `Log` by the _well name_
#
# All the `Log`s associated to a _well name_ can be extracted from the `Pack` subscripting it by _well name_. This operation will return:
# - a `Log` if there is only **one** file associated to the _well name_,
# - a `Pack` with all the files for the _well name_ if there are more than one file for it.
#
# #### getting a well with a single file:
# It return a `Log`:

# %%
las_pack['ALK001']
# Out:
#                DT
#              US/F
# DEPT
# 2584.8560  85.792
# 2584.7036  85.255
# 2584.5512  84.687
# 2584.3988  84.398
# 2584.2464  84.637
# ...           ...
# 0.7616        NaN
# 0.6092        NaN
# 0.4568        NaN
# 0.3044        NaN
# 0.1520        NaN
#
# [16961 rows x 1 columns]

# %% [markdown]
# It will be equivalent to extract the file by its index:

# %%
one_well = las_pack[0]
one_well
# Out:
#                DT
#              US/F
# DEPT
# 2584.8560  85.792
# 2584.7036  85.255
# 2584.5512  84.687
# 2584.3988  84.398
# 2584.2464  84.637
# ...           ...
# 0.7616        NaN
# 0.6092        NaN
# 0.4568        NaN
# 0.3044        NaN
# 0.1520        NaN
#
# [16961 rows x 1 columns]

# %% [markdown]
# #### getting a well with a more than one file:
# It returns a new `Pack`:

# %%
this_well_pack = las_pack['L5-13']
this_well_pack
# Out:
#     well  curves  steps index mnemonic index units  min index  max index  \
# 0  L5-13      28   1787           DEPT           M   3263.625   3486.875
# 1  L5-13      22   1141           DEPT           M   3253.625   3396.125
#
#                                     curves mnemonics  \
# 0  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
#
#                                                path
# 0  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                     ./sampledata\many\m87ad09.las

# %% [markdown]
# ## `Pack` concatenation
#
# The method `.concat()` helps to merge all the `.data` available in a `Pack` into a single `DataFrame`:

# %%
this_well = this_well_pack.concat()
this_well
# Out:
#             BIT CAL      CHT  CN CNC CNCF CNCQH DEVW DT24QI DTXXQI  ...  \
#             NaN  in      NaN  pu  pu   pu    pu  deg  us/ft  us/ft  ...
# DEPT                                                                ...
# 3263.625    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3263.750    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3263.875    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3264.000    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3264.125    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# ...         ...  ..      ...  ..  ..  ...   ...  ...    ...    ...  ...
# 3395.625  8.375 NaN -77.7724 NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3395.750  8.375 NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3395.875  8.375 NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3396.000  8.375 NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
# 3396.125    NaN NaN      NaN NaN NaN  NaN   NaN  NaN    NaN    NaN  ...
#
#                                                     source GRSL   K  KTH QHDL  \
#                                                        NaN gAPI pct gAPI  lbf
# DEPT
# 3263.625  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las  NaN NaN  NaN  NaN
# 3263.750  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las  NaN NaN  NaN  NaN
# 3263.875  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las  NaN NaN  NaN  NaN
# 3264.000  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las  NaN NaN  NaN  NaN
# 3264.125  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las  NaN NaN  NaN  NaN
# ...                                                    ...  ...  ..  ...  ...
# 3395.625                     ./sampledata\many\m87ad09.las  NaN NaN  NaN  NaN
# 3395.750                     ./sampledata\many\m87ad09.las  NaN NaN  NaN  NaN
# 3395.875                     ./sampledata\many\m87ad09.las  NaN NaN  NaN  NaN
# 3396.000                     ./sampledata\many\m87ad09.las  NaN NaN  NaN  NaN
# 3396.125                     ./sampledata\many\m87ad09.las  NaN NaN  NaN  NaN
#
#             RTHK RTHU     RUK  TH   WRM
#          ppm/pct    1 ppm/pct ppm ohm.m
# DEPT
# 3263.625     NaN  NaN     NaN NaN   NaN
# 3263.750     NaN  NaN     NaN NaN   NaN
# 3263.875     NaN  NaN     NaN NaN   NaN
# 3264.000     NaN  NaN     NaN NaN   NaN
# 3264.125     NaN  NaN     NaN NaN   NaN
# ...          ...  ...     ...  ..   ...
# 3395.625     NaN  NaN     NaN NaN   NaN
# 3395.750     NaN  NaN     NaN NaN   NaN
# 3395.875     NaN  NaN     NaN NaN   NaN
# 3396.000     NaN  NaN     NaN NaN   NaN
# 3396.125     NaN  NaN     NaN NaN   NaN
#
# [2928 rows x 39 columns]

# %%
type(this_well)
# Out:
# SimDataFrame

# %% [markdown]
# ## inserting data into a `Pack`
#
# ### + _(addition)_
#
# To add new `Log`s into a `Pack` is as simple as adding the `Pack` plus the `Log`. The **addition** method will return a new instance of `Pack` with a copy of each `Log` in the Pack.

# %%
this_well_pack
# Out:
#     well  curves  steps index mnemonic index units  min index  max index  \
# 0  L5-13      28   1787           DEPT           M   3263.625   3486.875
# 1  L5-13      22   1141           DEPT           M   3253.625   3396.125
#
#                                     curves mnemonics  \
# 0  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
#
#                                                path
# 0  ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                     ./sampledata\many\m87ad09.las

# %%
for each in this_well_pack:
    print(type(each), ', well name: ', each.name, sep='')
# Out:
# Log, well name: L5-13
# Log, well name: L5-13

# %%
print(type(one_log), ', well name: ', one_log.name, sep='')
# Out:
# Log, well name: P11-11

# %%
new_pack = this_well_pack + one_log
new_pack
# Out:
#      well  curves  steps index mnemonic index units  min index  max index  \
# 0   L5-13      28   1787           DEPT           M   3263.625   3486.875
# 1   L5-13      22   1141           DEPT           M   3253.625   3396.125
# 2  P11-11       6   2481           DEPT           M   2848.100   3096.100
#
#                                     curves mnemonics  \
# 0  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 2                       GR, VSH, NG, PHIE, PHIT, SWE
#
#                                                 path
# 0   ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                      ./sampledata\many\m87ad09.las
# 2  ./sampledata\many\P11-11_reservoir_evaluation.las

# %%
for each in new_pack:
    print(type(each), ', well name: ', each.name, sep='')
# Out:
# Log, well name: L5-13
# Log, well name: L5-13
# Log, well name: P11-11

# %% [markdown]
# ### `.append()` method
#
# A more efficient way to insert the data is to do it _inplace_.
# In order to append data inplace to a `Packp`, the __`.append()`__ method is the right way.
# This method requires a single item as argument. It can be:
# - a `Log`,
# - a `Pack`,
# - a `[`_`list of`_`Log ]`

# %%
this_well_pack.append(one_log)
this_well_pack
# Out:
#      well  curves  steps index mnemonic index units  min index  max index  \
# 0   L5-13      28   1787           DEPT           M   3263.625   3486.875
# 1   L5-13      22   1141           DEPT           M   3253.625   3396.125
# 2  P11-11       6   2481           DEPT           M   2848.100   3096.100
#
#                                     curves mnemonics  \
# 0  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 2                       GR, VSH, NG, PHIE, PHIT, SWE
#
#                                                 path
# 0   ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                      ./sampledata\many\m87ad09.las
# 2  ./sampledata\many\P11-11_reservoir_evaluation.las

# %% [markdown]
# ## joint of two `Pack`s
#
# The addition of two `Pack`s reluts in a new `Pack` whit the data from both Packs:

# %%
other_pack = las_pack['SCHOONEBEEK- 3']
other_pack
# Out:
#              well  curves  steps index mnemonic index units  min index  \
# 0  SCHOONEBEEK- 3       2   3518           DEPT           M   245.9736
# 1  SCHOONEBEEK- 3       2    804           DEPT           M   950.0000
# 2  SCHOONEBEEK- 3       2   1786           DEPT           M   700.0000
# 3  SCHOONEBEEK- 3       4    581           DEPT           M   745.5408
#
#    max index curves mnemonics  \
# 0   781.9644           SN, SP
# 1  1110.6000           SN, SP
# 2  1057.0000           SN, SP
# 3   861.5408   ES, LN, SN, SP
#
#                                                 path
# 0  ./sampledata\many\SCHOONEBEEK__3_RUN_01_RAW_OH...
# 1  ./sampledata\many\SCHOONEBEEK__3_RUN_04_RAW_OH...
# 2  ./sampledata\many\SCHOONEBEEK__3_RUN_03_RAW_OH...
# 3  ./sampledata\many\SCHOONEBEEK__3_RUN_02_RAW_OH...

# %%
for each in other_pack:
    print(type(each), ', well name: ', each.name, sep='')
# Out:
# Log, well name: SCHOONEBEEK- 3
# Log, well name: SCHOONEBEEK- 3
# Log, well name: SCHOONEBEEK- 3
# Log, well name: SCHOONEBEEK- 3

# %%
joint_pack = this_well_pack + other_pack
joint_pack
# Out:
#              well  curves  steps index mnemonic index units  min index  \
# 0           L5-13      28   1787           DEPT           M  3263.6250
# 1           L5-13      22   1141           DEPT           M  3253.6250
# 2          P11-11       6   2481           DEPT           M  2848.1000
# 3  SCHOONEBEEK- 3       2   3518           DEPT           M   245.9736
# 4  SCHOONEBEEK- 3       2    804           DEPT           M   950.0000
# 5  SCHOONEBEEK- 3       2   1786           DEPT           M   700.0000
# 6  SCHOONEBEEK- 3       4    581           DEPT           M   745.5408
#
#    max index                                   curves mnemonics  \
# 0  3486.8750  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  3396.1250  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 2  3096.1000                       GR, VSH, NG, PHIE, PHIT, SWE
# 3   781.9644                                             SN, SP
# 4  1110.6000                                             SN, SP
# 5  1057.0000                                             SN, SP
# 6   861.5408                                     ES, LN, SN, SP
#
#                                                 path
# 0   ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                      ./sampledata\many\m87ad09.las
# 2  ./sampledata\many\P11-11_reservoir_evaluation.las
# 3  ./sampledata\many\SCHOONEBEEK__3_RUN_01_RAW_OH...
# 4  ./sampledata\many\SCHOONEBEEK__3_RUN_04_RAW_OH...
# 5  ./sampledata\many\SCHOONEBEEK__3_RUN_03_RAW_OH...
# 6  ./sampledata\many\SCHOONEBEEK__3_RUN_02_RAW_OH...

# %%
for each in this_well_pack:
    print(type(each), 'well:', each.name)
# Out:
# Log well: L5-13
# Log well: L5-13
# Log well: P11-11

# %%
for each in other_pack:
    print(type(each), 'well:', each.name)
# Out:
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3

# %%
for each in joint_pack:
    print(type(each), 'well:', each.name)
# Out:
# Log well: L5-13
# Log well: L5-13
# Log well: P11-11
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3
# Log well: SCHOONEBEEK- 3

# %% [markdown]
# ### append in place
# As mentioned before, this task can be done inplance using the `.append()` method:

# %%
this_well_pack.append(other_pack)
this_well_pack
# Out:
#              well  curves  steps index mnemonic index units  min index  \
# 0           L5-13      28   1787           DEPT           M  3263.6250
# 1           L5-13      22   1141           DEPT           M  3253.6250
# 2          P11-11       6   2481           DEPT           M  2848.1000
# 3  SCHOONEBEEK- 3       2   3518           DEPT           M   245.9736
# 4  SCHOONEBEEK- 3       2    804           DEPT           M   950.0000
# 5  SCHOONEBEEK- 3       2   1786           DEPT           M   700.0000
# 6  SCHOONEBEEK- 3       4    581           DEPT           M   745.5408
#
#    max index                                   curves mnemonics  \
# 0  3486.8750  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  3396.1250  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 2  3096.1000                       GR, VSH, NG, PHIE, PHIT, SWE
# 3   781.9644                                             SN, SP
# 4  1110.6000                                             SN, SP
# 5  1057.0000                                             SN, SP
# 6   861.5408                                     ES, LN, SN, SP
#
#                                                 path
# 0   ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                      ./sampledata\many\m87ad09.las
# 2  ./sampledata\many\P11-11_reservoir_evaluation.las
# 3  ./sampledata\many\SCHOONEBEEK__3_RUN_01_RAW_OH...
# 4  ./sampledata\many\SCHOONEBEEK__3_RUN_04_RAW_OH...
# 5  ./sampledata\many\SCHOONEBEEK__3_RUN_03_RAW_OH...
# 6  ./sampledata\many\SCHOONEBEEK__3_RUN_02_RAW_OH...

# %% [markdown]
# # The `.copy()` method
#
# ## `Log.copy()`
#
# __`.copy()`__ method of a __Log__ will return a new `Log` instance with a copy of each dataframe in it contained:

# %%
log_copy = one_log.copy()
print('id original:', id(one_log), '\n    id data:', id(one_log.data))
print('id copy    :', id(log_copy), '\n    id data:', id(log_copy.data))
log_copy
# Out:
# id original: 1810977277648
#     id data: 1810975718896
# id copy    : 1810976230320
#     id data: 1810976237808
#                 GR       VSH   NG  PHIE      PHIT  SWE
#               gAPI         %      m3/m3     m3/m3
# DEPT
# 2848.1   94.649963  0.599209  0.0   0.0  0.018230  1.0
# 2848.2   97.408981  0.635115  0.0   0.0  0.018166  1.0
# 2848.3  100.315918  0.675204  0.0   0.0  0.018504  1.0
# 2848.4  102.986389  0.712926  0.0   0.0  0.020157  1.0
# 2848.5  105.348854  0.747440  0.0   0.0  0.023463  1.0
# ...            ...       ...  ...   ...       ...  ...
# 3095.7   66.164604  0.295831  0.0   NaN       NaN  NaN
# 3095.8   63.079655  0.269918  0.0   NaN       NaN  NaN
# 3095.9   60.334328  0.247381  0.0   NaN       NaN  NaN
# 3096.0   57.990810  0.228807  0.0   NaN       NaN  NaN
# 3096.1   56.599304  0.218156  0.0   NaN       NaN  NaN
#
# [2481 rows x 6 columns]

# %% [markdown]
# ## `Pack.copy()`
#
# __`.copy()`__ method of a __Pack__ will return a new `Pack` instance with a copy of each `Log` in it contained:

# %%
pack_copy = this_well_pack.copy()
print('id original:', id(this_well_pack), '\n    id data:', id(this_well_pack.data))
print('id copy    :', id(pack_copy), '\n    id data:', id(pack_copy.data))
pack_copy
# Out:
# id original: 1810977274752
#     id data: 1810974553152
# id copy    : 1810975426832
#     id data: 1810969138112
#              well  curves  steps index mnemonic index units  min index  \
# 0           L5-13      28   1787           DEPT           M  3263.6250
# 1           L5-13      22   1141           DEPT           M  3253.6250
# 2          P11-11       6   2481           DEPT           M  2848.1000
# 3  SCHOONEBEEK- 3       2   3518           DEPT           M   245.9736
# 4  SCHOONEBEEK- 3       2    804           DEPT           M   950.0000
# 5  SCHOONEBEEK- 3       2   1786           DEPT           M   700.0000
# 6  SCHOONEBEEK- 3       4    581           DEPT           M   745.5408
#
#    max index                                   curves mnemonics  \
# 0  3486.8750  BIT, CAL, CHT, CN, CNC, CNCF, CNCQH, DEVW, DT2...
# 1  3396.1250  BIT, CHT, GR, GRSL, K, KTH, M1R1, M1R2, M1R3, ...
# 2  3096.1000                       GR, VSH, NG, PHIE, PHIT, SWE
# 3   781.9644                                             SN, SP
# 4  1110.6000                                             SN, SP
# 5  1057.0000                                             SN, SP
# 6   861.5408                                     ES, LN, SN, SP
#
#                                                 path
# 0   ./sampledata\many\GDF_L5_13_8375IN_WL_RUN_A5.las
# 1                      ./sampledata\many\m87ad09.las
# 2  ./sampledata\many\P11-11_reservoir_evaluation.las
# 3  ./sampledata\many\SCHOONEBEEK__3_RUN_01_RAW_OH...
# 4  ./sampledata\many\SCHOONEBEEK__3_RUN_04_RAW_OH...
# 5  ./sampledata\many\SCHOONEBEEK__3_RUN_03_RAW_OH...
# 6  ./sampledata\many\SCHOONEBEEK__3_RUN_02_RAW_OH...
